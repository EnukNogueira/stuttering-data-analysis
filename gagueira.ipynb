# %%
import glob # Serve para localizar e listar os caminhos dos arquivos na pasta usando padrões de busca.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Carrega apenas os arquivos de rótulos (labels)
labels_files = glob.glob("archive/*_labels.csv")
falas_df = pd.concat([pd.read_csv(f) for f in labels_files], ignore_index=True)

# Carrega os arquivos de episódios separadamente 
episodes_files = glob.glob("archive/*_episodes.csv")
episodes_df = pd.concat([pd.read_csv(f) for f in episodes_files], ignore_index=True)

# Tabela principal de rótulos
falas_df.head(10)
# Out:
#           Show  EpId  ClipId    Start     Stop  Unsure  PoorAudioQuality  \
# 0  FluencyBank    10       0    88960   136960       0                 0
# 1  FluencyBank    10       1  1271520  1319520       0                 0
# 2  FluencyBank    10       2  1813760  1861760       0                 0
# 3  FluencyBank    10       3  1842720  1890720       0                 0
# 4  FluencyBank    10       4  1893280  1941280       0                 0
# 5  FluencyBank    10       5  1919520  1967520       0                 0
# 6  FluencyBank    10       6  1982720  2030720       0                 0
# 7  FluencyBank    10       7  2005600  2053600       0                 0
# 8  FluencyBank    10       8  2047520  2095520       0                 0
# 9  FluencyBank    10       9  2070400  2118400       0                 0
#
#    Prolongation  Block  SoundRep  WordRep  DifficultToUnderstand  \
# 0             0      1         0        0                      0
# ...

# %%
falas_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32321 entries, 0 to 32320
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Show                   32321 non-null  str
#  1   EpId                   32321 non-null  int64
#  2   ClipId                 32321 non-null  int64
#  3   Start                  32321 non-null  int64
#  4   Stop                   32321 non-null  int64
#  5   Unsure                 32321 non-null  int64
#  6   PoorAudioQuality       32321 non-null  int64
#  7   Prolongation           32321 non-null  int64
#  8   Block                  32321 non-null  int64
#  9   SoundRep               32321 non-null  int64
#  10  WordRep                32321 non-null  int64
#  11  DifficultToUnderstand  32321 non-null  int64
#  12  Interjection           32321 non-null  int64
#  13  NoStutteredWords       32321 non-null  int64
#  14  NaturalPause           32321 non-null  int64
# ...
